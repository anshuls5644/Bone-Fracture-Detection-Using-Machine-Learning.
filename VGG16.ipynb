# %%
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import VGG16
from tensorflow.keras.applications.vgg16 import preprocess_input
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint
from sklearn.utils.class_weight import compute_class_weight
import numpy as np
import matplotlib.pyplot as plt

# =========================
# CONFIG
# =========================
IMG_SIZE = 224   # VGG16 standard
BATCH_SIZE = 32
EPOCHS = 50
dataset_path = "dataset"

# =========================
# DATA GENERATOR
# =========================
datagen = ImageDataGenerator(
    preprocessing_function=preprocess_input,
    validation_split=0.2,
    rotation_range=30,
    zoom_range=0.3,
    width_shift_range=0.2,
    height_shift_range=0.2,
    shear_range=0.2,
    horizontal_flip=True,
    fill_mode="nearest"
)

train_gen = datagen.flow_from_directory(
    dataset_path,
    target_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    class_mode="categorical",
    subset="training"
)

val_gen = datagen.flow_from_directory(
    dataset_path,
    target_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    class_mode="categorical",
    subset="validation"
)

num_classes = train_gen.num_classes

print("Classes:", train_gen.class_indices)

# =========================
# CLASS WEIGHTS (IMPORTANT)
# =========================
class_weights = compute_class_weight(
    class_weight="balanced",
    classes=np.unique(train_gen.classes),
    y=train_gen.classes
)
class_weights = dict(enumerate(class_weights))

# =========================
# MODEL: VGG16
# =========================
base_model = VGG16(
    weights="imagenet",
    include_top=False,
    input_shape=(IMG_SIZE, IMG_SIZE, 3)
)

# Freeze most layers
for layer in base_model.layers[:-4]:
    layer.trainable = False

# Custom head
x = base_model.output
x = layers.GlobalAveragePooling2D()(x)

x = layers.BatchNormalization()(x)

x = layers.Dense(512, activation="relu")(x)
x = layers.Dropout(0.5)(x)

x = layers.Dense(256, activation="relu")(x)
x = layers.Dropout(0.4)(x)

output = layers.Dense(num_classes, activation="softmax")(x)

model = models.Model(inputs=base_model.input, outputs=output)

# =========================
# COMPILE
# =========================
model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4),
    loss="categorical_crossentropy",
    metrics=["accuracy"]
)

model.summary()

# =========================
# CALLBACKS
# =========================
early_stop = EarlyStopping(
    monitor="val_loss",
    patience=8,
    restore_best_weights=True
)

lr_reduce = ReduceLROnPlateau(
    monitor="val_loss",
    factor=0.3,
    patience=3,
    min_lr=1e-6
)

checkpoint = ModelCheckpoint(
    "best_vgg16_model.h5",
    monitor="val_accuracy",
    save_best_only=True,
    mode="max"
)

# =========================
# TRAIN
# =========================
history = model.fit(
    train_gen,
    validation_data=val_gen,
    epochs=EPOCHS,
    callbacks=[early_stop, lr_reduce, checkpoint],
    class_weight=class_weights
)

# =========================
# PLOTS
# =========================
plt.plot(history.history["accuracy"])
plt.plot(history.history["val_accuracy"])
plt.title("Accuracy")
plt.legend(["Train", "Val"])
plt.show()

plt.plot(history.history["loss"])
plt.plot(history.history["val_loss"])
plt.title("Loss")
plt.legend(["Train", "Val"])
plt.show()

# =========================
# SAVE
# =========================
model.save("bone_fracture_vgg16.h5")
print("Model Saved")

# =========================
# PREDICTION PART
# =========================
from tensorflow.keras.preprocessing import image

model = tf.keras.models.load_model("bone_fracture_vgg16.h5")

class_names = list(train_gen.class_indices.keys())

def fracture_severity(conf):
    if conf < 0.4:
        return "Very Mild", conf*100
    elif conf < 0.6:
        return "Mild", conf*100
    elif conf < 0.8:
        return "Moderate", conf*100
    else:
        return "Severe", conf*100

def predict(img_path):
    img = image.load_img(img_path, target_size=(IMG_SIZE, IMG_SIZE))
    img_array = image.img_to_array(img)
    img_array = np.expand_dims(img_array, axis=0)
    img_array = preprocess_input(img_array)

    pred = model.predict(img_array)
    idx = np.argmax(pred)
    conf = np.max(pred)

    label = class_names[idx]

    print("\nPrediction:", label)
    print("Confidence:", round(conf*100,2), "%")

    if label != "no_fracture":
        sev, perc = fracture_severity(conf)
        print("Severity:", sev)
        print("Severity %:", round(perc,2))

# TEST
predict("test_xray.jpg")
# Out:
# Found 1668 images belonging to 17 classes.
# Found 408 images belonging to 17 classes.
# Classes: {'Avulsion fracture': 0, 'Closed(simple) fracture': 1, 'Comminuted fracture': 2, 'Compression-Crush fracture': 3, 'Fracture Dislocation': 4, 'Greenstick fracture': 5, 'Hairline Fracture': 6, 'Impacted fracture': 7, 'Intra-articular fracture': 8, 'Longitudinal fracture': 9, 'Oblique fracture': 10, 'Open(compound) fracture': 11, 'Pathological fracture': 12, 'Segmental fracture': 13, 'Spiral Fracture': 14, 'Stress fracture': 15, 'Transverse fracture': 16}
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)             │ (None, 224, 224, 3)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block1_conv1 (Conv2D)                │ (None, 224, 224, 64)        │           1,792 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block1_conv2 (Conv2D)                │ (None, 224, 224, 64)        │          36,928 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block1_pool (MaxPooling2D)           │ (None, 112, 112, 64)        │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block2_conv1 (Conv2D)                │ (None, 112, 112, 128)       │          73,856 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block2_conv2 (Conv2D)                │ (None, 112, 112, 128)       │         147,584 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block2_pool (MaxPooling2D)           │ (None, 56, 56, 128)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block3_conv1 (Conv2D)                │ (None, 56, 56, 256)         │         295,168 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block3_conv2 (Conv2D)                │ (None, 56, 56, 256)         │         590,080 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block3_conv3 (Conv2D)                │ (None, 56, 56, 256)         │         590,080 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block3_pool (MaxPooling2D)           │ (None, 28, 28, 256)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block4_conv1 (Conv2D)                │ (None, 28, 28, 512)         │       1,180,160 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block4_conv2 (Conv2D)                │ (None, 28, 28, 512)         │       2,359,808 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block4_conv3 (Conv2D)                │ (None, 28, 28, 512)         │       2,359,808 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block4_pool (MaxPooling2D)           │ (None, 14, 14, 512)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block5_conv1 (Conv2D)                │ (None, 14, 14, 512)         │       2,359,808 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block5_conv2 (Conv2D)                │ (None, 14, 14, 512)         │       2,359,808 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block5_conv3 (Conv2D)                │ (None, 14, 14, 512)         │       2,359,808 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block5_pool (MaxPooling2D)           │ (None, 7, 7, 512)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ global_average_pooling2d             │ (None, 512)                 │               0 │
# │ (GlobalAveragePooling2D)             │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization                  │ (None, 512)                 │           2,048 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 512)                 │         262,656 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 512)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 256)                 │         131,328 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 256)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 17)                  │           4,369 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 15,115,089 (57.66 MB)
#  Trainable params: 7,478,801 (28.53 MB)
#  Non-trainable params: 7,636,288 (29.13 MB)
# Epoch 1/50
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 9s/step - accuracy: 0.0701 - loss: 3.4642
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 549s 10s/step - accuracy: 0.0785 - loss: 3.2781 - val_accuracy: 0.1201 - val_loss: 3.2369 - learning_rate: 1.0000e-04
# Epoch 2/50
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 6s/step - accuracy: 0.1506 - loss: 2.8722
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 395s 7s/step - accuracy: 0.1481 - loss: 2.8603 - val_accuracy: 0.1299 - val_loss: 3.0872 - learning_rate: 1.0000e-04
# Epoch 3/50
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - accuracy: 0.1432 - loss: 2.7488
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 309s 6s/step - accuracy: 0.1715 - loss: 2.6656 - val_accuracy: 0.1887 - val_loss: 2.7197 - learning_rate: 1.0000e-04
# Epoch 4/50
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - accuracy: 0.2056 - loss: 2.5170
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 302s 6s/step - accuracy: 0.1978 - loss: 2.5434 - val_accuracy: 0.2010 - val_loss: 2.5704 - learning_rate: 1.0000e-04
# Epoch 5/50
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 7s/step - accuracy: 0.2256 - loss: 2.4454
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 453s 9s/step - accuracy: 0.2266 - loss: 2.4322 - val_accuracy: 0.2206 - val_loss: 2.5374 - learning_rate: 1.0000e-04
# Epoch 6/50
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 448s 8s/step - accuracy: 0.2398 - loss: 2.3896 - val_accuracy: 0.2059 - val_loss: 2.5711 - learning_rate: 1.0000e-04
# Epoch 7/50
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 423s 8s/step - accuracy: 0.2362 - loss: 2.3341 - val_accuracy: 0.2181 - val_loss: 2.5179 - learning_rate: 1.0000e-04
# Epoch 8/50
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 412s 8s/step - accuracy: 0.2458 - loss: 2.3132 - val_accuracy: 0.1838 - val_loss: 2.5417 - learning_rate: 1.0000e-04
# Epoch 9/50
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 430s 8s/step - accuracy: 0.2596 - loss: 2.2651 - val_accuracy: 0.2181 - val_loss: 2.4634 - learning_rate: 1.0000e-04
# Epoch 10/50
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 365s 7s/step - accuracy: 0.2824 - loss: 2.1877 - val_accuracy: 0.2157 - val_loss: 2.4199 - learning_rate: 1.0000e-04
# Epoch 11/50
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 6s/step - accuracy: 0.2903 - loss: 2.1479
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 359s 7s/step - accuracy: 0.3022 - loss: 2.1209 - val_accuracy: 0.2696 - val_loss: 2.3375 - learning_rate: 1.0000e-04
# Epoch 12/50
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 357s 7s/step - accuracy: 0.2962 - loss: 2.1175 - val_accuracy: 0.2402 - val_loss: 2.4378 - learning_rate: 1.0000e-04
# Epoch 13/50
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 356s 7s/step - accuracy: 0.3273 - loss: 2.0573 - val_accuracy: 0.2525 - val_loss: 2.4043 - learning_rate: 1.0000e-04
# Epoch 14/50
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 6s/step - accuracy: 0.3300 - loss: 1.9830
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 357s 7s/step - accuracy: 0.3195 - loss: 2.0176 - val_accuracy: 0.2794 - val_loss: 2.3024 - learning_rate: 1.0000e-04
# Epoch 15/50
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 358s 7s/step - accuracy: 0.3483 - loss: 1.9312 - val_accuracy: 0.2696 - val_loss: 2.2847 - learning_rate: 1.0000e-04
# Epoch 16/50
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 356s 7s/step - accuracy: 0.3483 - loss: 1.9214 - val_accuracy: 0.2034 - val_loss: 2.4655 - learning_rate: 1.0000e-04
# Epoch 17/50
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 357s 7s/step - accuracy: 0.3453 - loss: 1.9454 - val_accuracy: 0.2549 - val_loss: 2.3648 - learning_rate: 1.0000e-04
# Epoch 18/50
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 356s 7s/step - accuracy: 0.3789 - loss: 1.8530 - val_accuracy: 0.2672 - val_loss: 2.3199 - learning_rate: 1.0000e-04
# Epoch 19/50
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 6s/step - accuracy: 0.3929 - loss: 1.7868
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 360s 7s/step - accuracy: 0.3981 - loss: 1.7963 - val_accuracy: 0.2941 - val_loss: 2.2903 - learning_rate: 3.0000e-05
# Epoch 20/50
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - accuracy: 0.3948 - loss: 1.8217
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 374s 7s/step - accuracy: 0.3933 - loss: 1.7933 - val_accuracy: 0.3064 - val_loss: 2.2232 - learning_rate: 3.0000e-05
# Epoch 21/50
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 6s/step - accuracy: 0.3905 - loss: 1.7816
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 393s 7s/step - accuracy: 0.4029 - loss: 1.7355 - val_accuracy: 0.3333 - val_loss: 2.1439 - learning_rate: 3.0000e-05
# Epoch 22/50
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 374s 7s/step - accuracy: 0.4065 - loss: 1.7014 - val_accuracy: 0.3088 - val_loss: 2.1985 - learning_rate: 3.0000e-05
# Epoch 23/50
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 359s 7s/step - accuracy: 0.4191 - loss: 1.6782 - val_accuracy: 0.3235 - val_loss: 2.1785 - learning_rate: 3.0000e-05
# Epoch 24/50
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 362s 7s/step - accuracy: 0.4197 - loss: 1.6286 - val_accuracy: 0.3088 - val_loss: 2.1785 - learning_rate: 3.0000e-05
# Epoch 25/50
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 6s/step - accuracy: 0.4330 - loss: 1.6438
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 359s 7s/step - accuracy: 0.4448 - loss: 1.6141 - val_accuracy: 0.3456 - val_loss: 2.2034 - learning_rate: 9.0000e-06
# Epoch 26/50
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 380s 7s/step - accuracy: 0.4382 - loss: 1.6380 - val_accuracy: 0.3137 - val_loss: 2.1896 - learning_rate: 9.0000e-06
# Epoch 27/50
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 7s/step - accuracy: 0.4501 - loss: 1.5637
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 448s 8s/step - accuracy: 0.4353 - loss: 1.6141 - val_accuracy: 0.3554 - val_loss: 2.1687 - learning_rate: 9.0000e-06
# Epoch 28/50
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 441s 8s/step - accuracy: 0.4508 - loss: 1.5789 - val_accuracy: 0.3284 - val_loss: 2.1472 - learning_rate: 2.7000e-06
# Epoch 29/50
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 472s 9s/step - accuracy: 0.4514 - loss: 1.5700 - val_accuracy: 0.3358 - val_loss: 2.1804 - learning_rate: 2.7000e-06
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Model Saved
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 741ms/step
#
# Prediction: Segmental fracture
# Confidence: 14.57 %
# Severity: Very Mild
# Severity %: 14.57
